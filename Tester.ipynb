# %% [markdown]
# # Testing the trained model

# %%
from matplotlib.pyplot import imshow
import numpy as np
import tensorflow as tf
from PIL import Image
# Out:
# /Users/xic/Desktop/research/code/note/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Loading the trained model
model = tf.keras.models.load_model('./Alzheimer_Detector.keras')

# %%
def names(number):
    if number == 0:
        return 'Non Demented'
    elif number == 1:
        return 'Mild Dementia'
    elif number == 2:
        return 'Moderate Dementia'
    elif number == 3:
        return 'Very Mild Dementia'
    else:
        return 'Error in Prediction'

# %%
img = Image.open('./input/Moderate Dementia/OAS1_0351_MR1_mpr-1_100.jpg')
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res=model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100)+ '% Confidence This Is '+ names(classification))
# Out:
# 99.99944% Confidence This Is Moderate Dementia

# %%
img = Image.open('./input/Very mild Dementia/OAS1_0021_MR1_mpr-3_126.jpg')
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res=model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100)+ '% Confidence This Is '+ names(classification))
# Out:
# 95.36799% Confidence This Is Very Mild Dementia

# %%
img = Image.open('./input/Mild Dementia/OAS1_0028_MR1_mpr-1_145.jpg')
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res=model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100)+ '% Confidence This Is '+ names(classification))
# Out:
# 99.9641% Confidence This Is Mild Dementia

# %%
img = Image.open('./input/Non Demented/OAS1_0011_MR1_mpr-3_144.jpg')
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res=model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100)+ '% Confidence This Is '+ names(classification))
# Out:
# 99.998405% Confidence This Is Non Demented
